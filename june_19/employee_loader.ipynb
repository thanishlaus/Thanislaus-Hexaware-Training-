# %%
employee_data = [
(101,"Rahul","IT",50000),
(102,"Priya","HR",45000),
(103,"Amit","Finance",55000),
(104,"Sneha","IT",60000),
(105,"Farhan","Sales",40000)
]

columns = [
"emp_id",
"name",
"department",
"salary"
]

employee_df = spark.createDataFrame(
    employee_data,
    columns
)

employee_df.show()
# Out:
# +------+------+----------+------+
# |emp_id|  name|department|salary|
# +------+------+----------+------+
# |   101| Rahul|        IT| 50000|
# |   102| Priya|        HR| 45000|
# |   103|  Amit|   Finance| 55000|
# |   104| Sneha|        IT| 60000|
# |   105|Farhan|     Sales| 40000|
# +------+------+----------+------+

# %%
employee_df.show()
# Out:
# +------+------+----------+------+
# |emp_id|  name|department|salary|
# +------+------+----------+------+
# |   101| Rahul|        IT| 50000|
# |   102| Priya|        HR| 45000|
# |   103|  Amit|   Finance| 55000|
# |   104| Sneha|        IT| 60000|
# |   105|Farhan|     Sales| 40000|
# +------+------+----------+------+

# %%
print("Employee Load Completed")
# Out:
# Employee Load Completed
