# %%
data=[
    (101,"Rahul",75000),
    (102,"Priya",85000),
    (103,"Amit",65000)
]
df=spark.createDataFrame(data,['emp_id','name','salary'])

# %%
df = spark.createDataFrame(
    data,
    ["emp_id","name","salary"]
)

# %%
df.write.format("delta") \
.save("/Volumes/databrick_hexa_7405613493089439/default/hexa-volume")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-7279173050742624>, line 2
#       1 df.write.format("delta") \
# ----> 2 .save("/Volumes/databrick_hexa_7405613493089439/default/hexa-volume")
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/readwriter.py:703, in DataFrameWriter.save(self, path, format, mode, partitionBy, **options)
#     701     self.format(format)
#     702 self._write.path = path
# --> 703 _, _, ei = self._spark.client.execute_command(
#     704     self._write.command(self._spark.client), self._write.observations
#     705 )
#     706 self._callback(ei)
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:1538, in SparkConnectClient.execute_command(self, command, observations, extra_request_metadata)
#    1536     req.user_context.user_id = self._user_id
# ...

# %%
delta_df = spark.read.format("delta") \
.load("/Volumes/databrick_hexa_7405613493089439/default/hexa-volume")

display(delta_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>salary</th></tr></thead><tbody><tr><td>101</td><td>Rahul</td><td>75000</td></tr><tr><td>102</td><td>Priya</td><td>85000</td></tr><tr><td>103</td><td>Amit</td><td>65000</td></tr></tbody></table></div>

# %%
df.write.format("delta") \
.saveAsTable("employees")

# %%
# %sql
select * from employees;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>salary</th></tr></thead><tbody><tr><td>101</td><td>Rahul</td><td>75000</td></tr><tr><td>102</td><td>Priya</td><td>85000</td></tr><tr><td>103</td><td>Amit</td><td>65000</td></tr></tbody></table></div>

# %%
# %sql
CREATE OR REPLACE TABLE employees_delta
(
    emp_id INT,
    name STRING,
    salary INT
    city STRING
)
USING DELTA
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-7279173050742674>, line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'CREATE TABLE employees_delta\n(\n    emp_id INT,\n    name STRING,\n    salary INT\n)\nUSING DELTA\n')
#
# File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
# %sql
INSERT INTO employees_delta
VALUES
(101,'Rahul',75000),
(102,'Priya',85000)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>2</td><td>2</td></tr></tbody></table></div>

# %%
# %sql
select * from employees_delta
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>salary</th></tr></thead><tbody><tr><td>101</td><td>Rahul</td><td>75000</td></tr><tr><td>102</td><td>Priya</td><td>85000</td></tr></tbody></table></div>

# %%
# %sql DESCRIBE HISTORY employees
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
OPTIMIZE employees
ZORDER BY (emp_id)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td></td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 0, List(minCubeSize(107374182400), List(0, 0), List(1, 1308), 0, List(0, 0), 0, null), null, 0, 0, 1, 1, false, 0, 0, 1781691070716, 1781691071240, 8, 0, null, List(0, 0), null, 3, 3, 0, 0, null, null)</td></tr></tbody></table></div>

# %%
# %sql VACUUM employees
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody><tr><td></td></tr></tbody></table></div>
