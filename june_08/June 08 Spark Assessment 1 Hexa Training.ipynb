# %%
# !pip install pyspark

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("PySpark Day 1") \
    .getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://34dc24719c44:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySpark Day 1</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
data = [
    (101, "Rahul Sharma", "Data Engineering", 75000, "Hyderabad"),
    (102, "Priya Reddy", "AI Engineering", 85000, "Bangalore"),
    (103, "Amit Kumar", "Data Engineering", 65000, "Mumbai"),
    (104, "Sneha Patel", "Data Science", 95000, "Chennai"),
    (105, "Farhan Ali", "Cloud Engineering", 80000, "Delhi")
]

# %%
columns = [
    "employee_id",
    "name",
    "department",
    "salary",
    "city"
]

# %%
df=spark.createDataFrame(data,columns)
df.show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# +-----------+------------+-----------------+------+---------+

# %%
df.printSchema()
# Out:
# root
#  |-- employee_id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- department: string (nullable = true)
#  |-- salary: long (nullable = true)
#  |-- city: string (nullable = true)

# %%
df.select("name","salary").show()
# Out:
# +------------+------+
# |        name|salary|
# +------------+------+
# |Rahul Sharma| 75000|
# | Priya Reddy| 85000|
# |  Amit Kumar| 65000|
# | Sneha Patel| 95000|
# |  Farhan Ali| 80000|
# +------------+------+

# %%
df.filter(df.salary>80000).show()
# Out:
# +-----------+-----------+--------------+------+---------+
# |employee_id|       name|    department|salary|     city|
# +-----------+-----------+--------------+------+---------+
# |        102|Priya Reddy|AI Engineering| 85000|Bangalore|
# |        104|Sneha Patel|  Data Science| 95000|  Chennai|
# +-----------+-----------+--------------+------+---------+

# %%
df.filter(df.city=="Hyderabad").show()
# Out:
# +-----------+------------+----------------+------+---------+
# |employee_id|        name|      department|salary|     city|
# +-----------+------------+----------------+------+---------+
# |        101|Rahul Sharma|Data Engineering| 75000|Hyderabad|
# +-----------+------------+----------------+------+---------+

# %%
df.orderBy(df.salary.desc()).show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# +-----------+------------+-----------------+------+---------+

# %%
df.orderBy("salary").show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|
# +-----------+------------+-----------------+------+---------+

# %%
from pyspark.sql.functions import col
df_bonus= df.withColumn(
    "bonus",
    col("salary")*0.10
)
df_bonus.show()
# Out:
# +-----------+------------+-----------------+------+---------+------+
# |employee_id|        name|       department|salary|     city| bonus|
# +-----------+------------+-----------------+------+---------+------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|7500.0|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|8500.0|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|6500.0|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|9500.0|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|8000.0|
# +-----------+------------+-----------------+------+---------+------+

# %%
df_renamed=df.withColumnRenamed(
    "salary",
    "monthly_salary"
)
df_renamed.show()
# Out:
# +-----------+------------+-----------------+--------------+---------+
# |employee_id|        name|       department|monthly_salary|     city|
# +-----------+------------+-----------------+--------------+---------+
# |        101|Rahul Sharma| Data Engineering|         75000|Hyderabad|
# |        102| Priya Reddy|   AI Engineering|         85000|Bangalore|
# |        103|  Amit Kumar| Data Engineering|         65000|   Mumbai|
# |        104| Sneha Patel|     Data Science|         95000|  Chennai|
# |        105|  Farhan Ali|Cloud Engineering|         80000|    Delhi|
# +-----------+------------+-----------------+--------------+---------+

# %%
df.groupBy("department").count().show()
# Out:
# +-----------------+-----+
# |       department|count|
# +-----------------+-----+
# | Data Engineering|    2|
# |   AI Engineering|    1|
# |Cloud Engineering|    1|
# |     Data Science|    1|
# +-----------------+-----+

# %%
#1
df.select("employee_id","name").show()
# Out:
# +-----------+------------+
# |employee_id|        name|
# +-----------+------------+
# |        101|Rahul Sharma|
# |        102| Priya Reddy|
# |        103|  Amit Kumar|
# |        104| Sneha Patel|
# |        105|  Farhan Ali|
# +-----------+------------+

# %%
#2
df.select("name","salary","city").show(),
# Out:
# +------------+------+---------+
# |        name|salary|     city|
# +------------+------+---------+
# |Rahul Sharma| 75000|Hyderabad|
# | Priya Reddy| 85000|Bangalore|
# |  Amit Kumar| 65000|   Mumbai|
# | Sneha Patel| 95000|  Chennai|
# |  Farhan Ali| 80000|    Delhi|
# +------------+------+---------+
# (None,)

# %%
#3
df.select("employee_id","name","salary","department").show(),
# Out:
# +-----------+------------+------+-----------------+
# |employee_id|        name|salary|       department|
# +-----------+------------+------+-----------------+
# |        101|Rahul Sharma| 75000| Data Engineering|
# |        102| Priya Reddy| 85000|   AI Engineering|
# |        103|  Amit Kumar| 65000| Data Engineering|
# |        104| Sneha Patel| 95000|     Data Science|
# |        105|  Farhan Ali| 80000|Cloud Engineering|
# +-----------+------------+------+-----------------+
# (None,)

# %%
#4
df.filter(df.salary>70000).show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# +-----------+------------+-----------------+------+---------+

# %%
#5
df.filter(df.salary<80000).show()
# Out:
# +-----------+------------+----------------+------+---------+
# |employee_id|        name|      department|salary|     city|
# +-----------+------------+----------------+------+---------+
# |        101|Rahul Sharma|Data Engineering| 75000|Hyderabad|
# |        103|  Amit Kumar|Data Engineering| 65000|   Mumbai|
# +-----------+------------+----------------+------+---------+

# %%
#6
df.filter(df.city=="Mumbai").show()
# Out:
# +-----------+----------+----------------+------+------+
# |employee_id|      name|      department|salary|  city|
# +-----------+----------+----------------+------+------+
# |        103|Amit Kumar|Data Engineering| 65000|Mumbai|
# +-----------+----------+----------------+------+------+

# %%
#7
df.filter(df.city=="Bangalore").show()
# Out:
# +-----------+-----------+--------------+------+---------+
# |employee_id|       name|    department|salary|     city|
# +-----------+-----------+--------------+------+---------+
# |        102|Priya Reddy|AI Engineering| 85000|Bangalore|
# +-----------+-----------+--------------+------+---------+

# %%
#8
df.filter(df.department=="Data Engineering").show()
# Out:
# +-----------+------------+----------------+------+---------+
# |employee_id|        name|      department|salary|     city|
# +-----------+------------+----------------+------+---------+
# |        101|Rahul Sharma|Data Engineering| 75000|Hyderabad|
# |        103|  Amit Kumar|Data Engineering| 65000|   Mumbai|
# +-----------+------------+----------------+------+---------+

# %%
#9
df.filter(df.department=="AI Engineering").show()
# Out:
# +-----------+-----------+--------------+------+---------+
# |employee_id|       name|    department|salary|     city|
# +-----------+-----------+--------------+------+---------+
# |        102|Priya Reddy|AI Engineering| 85000|Bangalore|
# +-----------+-----------+--------------+------+---------+

# %%
#10
df.filter((df.salary>=70000) & (df.salary<=90000)).show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# +-----------+------------+-----------------+------+---------+

# %%
#11
df.filter((df.city=="Hyderabad") & (df.salary>=70000)).show()
# Out:
# +-----------+------------+----------------+------+---------+
# |employee_id|        name|      department|salary|     city|
# +-----------+------------+----------------+------+---------+
# |        101|Rahul Sharma|Data Engineering| 75000|Hyderabad|
# +-----------+------------+----------------+------+---------+

# %%
#12
df.filter((df.city=="Bangalore") & (df.city=="Chennai")).show()
# Out:
# +-----------+----+----------+------+----+
# |employee_id|name|department|salary|city|
# +-----------+----+----------+------+----+
# +-----------+----+----------+------+----+

# %%
#13
df.filter(df.city.isin("Hyderabad","Mumbai","Delhi")).show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# +-----------+------------+-----------------+------+---------+

# %%
#14
df.filter(
    df.department.isin(
        "Data Engineering",
        "AI Engineering"
    )
).show()
# Out:
# +-----------+------------+----------------+------+---------+
# |employee_id|        name|      department|salary|     city|
# +-----------+------------+----------------+------+---------+
# |        101|Rahul Sharma|Data Engineering| 75000|Hyderabad|
# |        102| Priya Reddy|  AI Engineering| 85000|Bangalore|
# |        103|  Amit Kumar|Data Engineering| 65000|   Mumbai|
# +-----------+------------+----------------+------+---------+

# %%
#15
df.orderBy("salary").show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|
# +-----------+------------+-----------------+------+---------+

# %%
#16
df.orderBy(df.salary.desc()).show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# +-----------+------------+-----------------+------+---------+

# %%
#17
df.orderBy("name").show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|
# +-----------+------------+-----------------+------+---------+

# %%
#18
df.orderBy("city","salary").show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# +-----------+------------+-----------------+------+---------+

# %%
#19
from pyspark.sql.functions import col
df = df.withColumn(
    "bonus",
    col("salary") * 0.10
)

df.show()
# Out:
# +-----------+------------+-----------------+------+---------+------+
# |employee_id|        name|       department|salary|     city| bonus|
# +-----------+------------+-----------------+------+---------+------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|7500.0|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|8500.0|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|6500.0|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|9500.0|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|8000.0|
# +-----------+------------+-----------------+------+---------+------+

# %%
#20
df = df.withColumn(
    "tax",
    col("salary") * 0.05
)

df.show()
# Out:
# +-----------+------------+-----------------+------+---------+------+------+
# |employee_id|        name|       department|salary|     city| bonus|   tax|
# +-----------+------------+-----------------+------+---------+------+------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|7500.0|3750.0|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|8500.0|4250.0|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|6500.0|3250.0|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|9500.0|4750.0|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|8000.0|4000.0|
# +-----------+------------+-----------------+------+---------+------+------+

# %%
#21
df = df.withColumn(
    "annual_salary",
    col("salary") * 12
)

df.show()
# Out:
# +-----------+------------+-----------------+------+---------+------+------+-------------+
# |employee_id|        name|       department|salary|     city| bonus|   tax|annual_salary|
# +-----------+------------+-----------------+------+---------+------+------+-------------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|7500.0|3750.0|       900000|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|8500.0|4250.0|      1020000|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|6500.0|3250.0|       780000|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|9500.0|4750.0|      1140000|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|8000.0|4000.0|       960000|
# +-----------+------------+-----------------+------+---------+------+------+-------------+

# %%
#22
df = df.withColumn(
    "salary_after_bonus",
    col("salary") + col("bonus")
)

df.show()
# Out:
# +-----------+------------+-----------------+------+---------+------+------+-------------+------------------+
# |employee_id|        name|       department|salary|     city| bonus|   tax|annual_salary|salary_after_bonus|
# +-----------+------------+-----------------+------+---------+------+------+-------------+------------------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|7500.0|3750.0|       900000|           82500.0|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|8500.0|4250.0|      1020000|           93500.0|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|6500.0|3250.0|       780000|           71500.0|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|9500.0|4750.0|      1140000|          104500.0|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|8000.0|4000.0|       960000|           88000.0|
# +-----------+------------+-----------------+------+---------+------+------+-------------+------------------+

# %%
#23
df = df.withColumnRenamed(
    "salary",
    "monthly_salary"
)

df.show()
# Out:
# +-----------+------------+-----------------+--------------+---------+------+------+-------------+------------------+
# |employee_id|        name|       department|monthly_salary|     city| bonus|   tax|annual_salary|salary_after_bonus|
# +-----------+------------+-----------------+--------------+---------+------+------+-------------+------------------+
# |        101|Rahul Sharma| Data Engineering|         75000|Hyderabad|7500.0|3750.0|       900000|           82500.0|
# |        102| Priya Reddy|   AI Engineering|         85000|Bangalore|8500.0|4250.0|      1020000|           93500.0|
# |        103|  Amit Kumar| Data Engineering|         65000|   Mumbai|6500.0|3250.0|       780000|           71500.0|
# |        104| Sneha Patel|     Data Science|         95000|  Chennai|9500.0|4750.0|      1140000|          104500.0|
# |        105|  Farhan Ali|Cloud Engineering|         80000|    Delhi|8000.0|4000.0|       960000|           88000.0|
# ...

# %%
#24
df = df.withColumnRenamed(
    "department",
    "team"
)

df.show()
# Out:
# +-----------+------------+-----------------+--------------+---------+------+------+-------------+------------------+
# |employee_id|        name|             team|monthly_salary|     city| bonus|   tax|annual_salary|salary_after_bonus|
# +-----------+------------+-----------------+--------------+---------+------+------+-------------+------------------+
# |        101|Rahul Sharma| Data Engineering|         75000|Hyderabad|7500.0|3750.0|       900000|           82500.0|
# |        102| Priya Reddy|   AI Engineering|         85000|Bangalore|8500.0|4250.0|      1020000|           93500.0|
# |        103|  Amit Kumar| Data Engineering|         65000|   Mumbai|6500.0|3250.0|       780000|           71500.0|
# |        104| Sneha Patel|     Data Science|         95000|  Chennai|9500.0|4750.0|      1140000|          104500.0|
# |        105|  Farhan Ali|Cloud Engineering|         80000|    Delhi|8000.0|4000.0|       960000|           88000.0|
# ...

# %%
df = df.withColumnRenamed("salary", "monthly_salary")

df = df.withColumnRenamed("department", "team")

# %%
#25
df.agg({"monthly_salary":"sum"}).show()
# Out:
# +-------------------+
# |sum(monthly_salary)|
# +-------------------+
# |             400000|
# +-------------------+

# %%
#26
df.agg({"monthly_salary":"avg"}).show()
# Out:
# +-------------------+
# |avg(monthly_salary)|
# +-------------------+
# |            80000.0|
# +-------------------+

# %%
#27
df.agg({"monthly_salary":"max"}).show()
# Out:
# +-------------------+
# |max(monthly_salary)|
# +-------------------+
# |              95000|
# +-------------------+

# %%
#28
df.agg({"monthly_salary":"min"}).show()
# Out:
# +-------------------+
# |min(monthly_salary)|
# +-------------------+
# |              65000|
# +-------------------+

# %%
#29
df.agg({"employee_id":"count"}).show()
# Out:
# +------------------+
# |count(employee_id)|
# +------------------+
# |                 5|
# +------------------+

# %%
#30
df.groupBy("team").count().show()
# Out:
# +-----------------+-----+
# |             team|count|
# +-----------------+-----+
# | Data Engineering|    2|
# |   AI Engineering|    1|
# |Cloud Engineering|    1|
# |     Data Science|    1|
# +-----------------+-----+

# %%
#31
df.groupBy("team").avg("monthly_salary").show()
# Out:
# +-----------------+-------------------+
# |             team|avg(monthly_salary)|
# +-----------------+-------------------+
# | Data Engineering|            70000.0|
# |   AI Engineering|            85000.0|
# |Cloud Engineering|            80000.0|
# |     Data Science|            95000.0|
# +-----------------+-------------------+

# %%
#32
df.groupBy("team").max("monthly_salary").show()
# Out:
# +-----------------+-------------------+
# |             team|max(monthly_salary)|
# +-----------------+-------------------+
# | Data Engineering|              75000|
# |   AI Engineering|              85000|
# |Cloud Engineering|              80000|
# |     Data Science|              95000|
# +-----------------+-------------------+

# %%
#33
df.groupBy("team").min("monthly_salary").show()
# Out:
# +-----------------+-------------------+
# |             team|min(monthly_salary)|
# +-----------------+-------------------+
# | Data Engineering|              65000|
# |   AI Engineering|              85000|
# |Cloud Engineering|              80000|
# |     Data Science|              95000|
# +-----------------+-------------------+

# %%
#34
df.groupBy("team").sum("monthly_salary").show()
# Out:
# +-----------------+-------------------+
# |             team|sum(monthly_salary)|
# +-----------------+-------------------+
# | Data Engineering|             140000|
# |   AI Engineering|              85000|
# |Cloud Engineering|              80000|
# |     Data Science|              95000|
# +-----------------+-------------------+

# %%
#35
df.select("team").distinct().show()
# Out:
# +-----------------+
# |             team|
# +-----------------+
# | Data Engineering|
# |   AI Engineering|
# |Cloud Engineering|
# |     Data Science|
# +-----------------+

# %%
#36
df.select("city").distinct().show()
# Out:
# +---------+
# |     city|
# +---------+
# |Bangalore|
# |Hyderabad|
# |  Chennai|
# |   Mumbai|
# |    Delhi|
# +---------+

# %%
#37
df.select("team").distinct().count()
# Out:
# 4

# %%
#38
df.orderBy(df.monthly_salary.desc()).show(3)
# Out:
# +-----------+-----------+-----------------+--------------+---------+------+------+-------------+------------------+
# |employee_id|       name|             team|monthly_salary|     city| bonus|   tax|annual_salary|salary_after_bonus|
# +-----------+-----------+-----------------+--------------+---------+------+------+-------------+------------------+
# |        104|Sneha Patel|     Data Science|         95000|  Chennai|9500.0|4750.0|      1140000|          104500.0|
# |        102|Priya Reddy|   AI Engineering|         85000|Bangalore|8500.0|4250.0|      1020000|           93500.0|
# |        105| Farhan Ali|Cloud Engineering|         80000|    Delhi|8000.0|4000.0|       960000|           88000.0|
# +-----------+-----------+-----------------+--------------+---------+------+------+-------------+------------------+
# only showing top 3 rows

# %%
#39
df.orderBy(df.monthly_salary.asc()).show(1)
# Out:
# +-----------+----------+----------------+--------------+------+------+------+-------------+------------------+
# |employee_id|      name|            team|monthly_salary|  city| bonus|   tax|annual_salary|salary_after_bonus|
# +-----------+----------+----------------+--------------+------+------+------+-------------+------------------+
# |        103|Amit Kumar|Data Engineering|         65000|Mumbai|6500.0|3250.0|       780000|           71500.0|
# +-----------+----------+----------------+--------------+------+------+------+-------------+------------------+
# only showing top 1 row

# %%
#40
from pyspark.sql.functions import col
df.filter(
    col("name").startswith("R")
).show()
# Out:
# +-----------+------------+----------------+--------------+---------+------+------+-------------+------------------+
# |employee_id|        name|            team|monthly_salary|     city| bonus|   tax|annual_salary|salary_after_bonus|
# +-----------+------------+----------------+--------------+---------+------+------+-------------+------------------+
# |        101|Rahul Sharma|Data Engineering|         75000|Hyderabad|7500.0|3750.0|       900000|           82500.0|
# +-----------+------------+----------------+--------------+---------+------+------+-------------+------------------+

# %%
#41
from pyspark.sql.functions import col

df.filter(
    col("name").contains("a")
).show()
# Out:
# +-----------+------------+-----------------+--------------+---------+------+------+-------------+------------------+
# |employee_id|        name|             team|monthly_salary|     city| bonus|   tax|annual_salary|salary_after_bonus|
# +-----------+------------+-----------------+--------------+---------+------+------+-------------+------------------+
# |        101|Rahul Sharma| Data Engineering|         75000|Hyderabad|7500.0|3750.0|       900000|           82500.0|
# |        102| Priya Reddy|   AI Engineering|         85000|Bangalore|8500.0|4250.0|      1020000|           93500.0|
# |        103|  Amit Kumar| Data Engineering|         65000|   Mumbai|6500.0|3250.0|       780000|           71500.0|
# |        104| Sneha Patel|     Data Science|         95000|  Chennai|9500.0|4750.0|      1140000|          104500.0|
# |        105|  Farhan Ali|Cloud Engineering|         80000|    Delhi|8000.0|4000.0|       960000|           88000.0|
# ...

# %%
#42
from pyspark.sql.functions import col

df.filter(
    col("team").contains("Engineering")
).show()
# Out:
# +-----------+------------+-----------------+--------------+---------+------+------+-------------+------------------+
# |employee_id|        name|             team|monthly_salary|     city| bonus|   tax|annual_salary|salary_after_bonus|
# +-----------+------------+-----------------+--------------+---------+------+------+-------------+------------------+
# |        101|Rahul Sharma| Data Engineering|         75000|Hyderabad|7500.0|3750.0|       900000|           82500.0|
# |        102| Priya Reddy|   AI Engineering|         85000|Bangalore|8500.0|4250.0|      1020000|           93500.0|
# |        103|  Amit Kumar| Data Engineering|         65000|   Mumbai|6500.0|3250.0|       780000|           71500.0|
# |        105|  Farhan Ali|Cloud Engineering|         80000|    Delhi|8000.0|4000.0|       960000|           88000.0|
# +-----------+------------+-----------------+--------------+---------+------+------+-------------+------------------+

# %%
#43
from pyspark.sql.functions import when, col

df = df.withColumn(
    "salary_category",
    when(col("monthly_salary") >= 85000, "High")
    .when(col("monthly_salary") >= 75000, "Medium")
    .otherwise("Low")
)

df.show()
# Out:
# +-----------+------------+-----------------+--------------+---------+------+------+-------------+------------------+---------------+
# |employee_id|        name|             team|monthly_salary|     city| bonus|   tax|annual_salary|salary_after_bonus|salary_category|
# +-----------+------------+-----------------+--------------+---------+------+------+-------------+------------------+---------------+
# |        101|Rahul Sharma| Data Engineering|         75000|Hyderabad|7500.0|3750.0|       900000|           82500.0|         Medium|
# |        102| Priya Reddy|   AI Engineering|         85000|Bangalore|8500.0|4250.0|      1020000|           93500.0|           High|
# |        103|  Amit Kumar| Data Engineering|         65000|   Mumbai|6500.0|3250.0|       780000|           71500.0|            Low|
# |        104| Sneha Patel|     Data Science|         95000|  Chennai|9500.0|4750.0|      1140000|          104500.0|           High|
# ...

# %%
#44
df.agg({"monthly_salary":"count"}).show()
# Out:
# +---------------------+
# |count(monthly_salary)|
# +---------------------+
# |                    5|
# +---------------------+

# %%
#45
df.select(
    "employee_id",
    "name",
    "team",
    "monthly_salary",
    "bonus",
    "annual_salary"
).show()
# Out:
# +-----------+------------+-----------------+--------------+------+-------------+
# |employee_id|        name|             team|monthly_salary| bonus|annual_salary|
# +-----------+------------+-----------------+--------------+------+-------------+
# |        101|Rahul Sharma| Data Engineering|         75000|7500.0|       900000|
# |        102| Priya Reddy|   AI Engineering|         85000|8500.0|      1020000|
# |        103|  Amit Kumar| Data Engineering|         65000|6500.0|       780000|
# |        104| Sneha Patel|     Data Science|         95000|9500.0|      1140000|
# |        105|  Farhan Ali|Cloud Engineering|         80000|8000.0|       960000|
# +-----------+------------+-----------------+--------------+------+-------------+
