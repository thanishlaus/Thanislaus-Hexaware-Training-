# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder \
.appName("RDD") \
.getOrCreate()

# %%
transactions = [
"DEPOSIT",
"WITHDRAW",
"TRANSFER",
"DEPOSIT",
"BALANCE_CHECK",
"TRANSFER",
"DEPOSIT",
"WITHDRAW",
"LOAN_PAYMENT",
"DEPOSIT",
"TRANSFER",
"WITHDRAW",
"DEPOSIT",
"BALANCE_CHECK",
"TRANSFER",
"DEPOSIT",
"WITHDRAW",
"LOAN_PAYMENT",
"TRANSFER",
"DEPOSIT",
"WITHDRAW",
"DEPOSIT",
"TRANSFER",
"BALANCE_CHECK",
"WITHDRAW",
"DEPOSIT",
"TRANSFER",
"LOAN_PAYMENT",
"DEPOSIT",
"WITHDRAW",
"TRANSFER",
"DEPOSIT",
"BALANCE_CHECK",
"TRANSFER",
"WITHDRAW",
"DEPOSIT",
"TRANSFER",
"LOAN_PAYMENT",
"DEPOSIT",
"WITHDRAW",
"TRANSFER",
"BALANCE_CHECK",
"DEPOSIT",
"TRANSFER",
"WITHDRAW",
"LOAN_PAYMENT",
"DEPOSIT",
"TRANSFER",
"BALANCE_CHECK",
"DEPOSIT"
]

rdd = spark.sparkContext.parallelize(transactions)

# %%
# 1 Display all transactions
rdd.collect()
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT']

# %%
#2
rdd.count()
# Out:
# 50

# %%
#3
rdd.first()
# Out:
# 'DEPOSIT'

# %%
#4
rdd.take(15)
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER']

# %%
#5
rdd.distinct().collect()
# Out:
# ['DEPOSIT', 'WITHDRAW', 'TRANSFER', 'BALANCE_CHECK', 'LOAN_PAYMENT']

# %%
#6
rdd.distinct().count()
# Out:
# 5

# %%
#7
rdd.sortBy(lambda x: x).collect()
# Out:
# ['BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'TRANSFER',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW']

# %%
#8
rdd.map(lambda x: x.lower()).collect()
# Out:
# ['deposit',
#  'withdraw',
#  'transfer',
#  'deposit',
#  'balance_check',
#  'transfer',
#  'deposit',
#  'withdraw',
#  'loan_payment',
#  'deposit',
#  'transfer',
#  'withdraw',
#  'deposit',
#  'balance_check',
#  'transfer',
#  'deposit',
#  'withdraw',
#  'loan_payment',
#  'transfer',
#  'deposit',
#  'withdraw',
#  'deposit',
#  'transfer',
#  'balance_check',
#  'withdraw',
#  'deposit',
#  'transfer',
#  'loan_payment',
#  'deposit',
#  'withdraw',
#  'transfer',
#  'deposit',
#  'balance_check',
#  'transfer',
#  'withdraw',
#  'deposit',
#  'transfer',
#  'loan_payment',
#  'deposit',
#  'withdraw',
#  'transfer',
#  'balance_check',
#  'deposit',
#  'transfer',
#  'withdraw',
#  'loan_payment',
#  'deposit',
#  'transfer',
#  'balance_check',
#  'deposit']

# %%
#9
rdd.map(lambda x: x.upper()).collect()
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT']

# %%
#10
rdd.map(lambda x: (x, len(x))).collect()
# Out:
# [('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('BALANCE_CHECK', 13),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('LOAN_PAYMENT', 12),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('WITHDRAW', 8),
#  ('DEPOSIT', 7),
#  ('BALANCE_CHECK', 13),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('LOAN_PAYMENT', 12),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('BALANCE_CHECK', 13),
#  ('WITHDRAW', 8),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('LOAN_PAYMENT', 12),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('TRANSFER', 8),
#  ('DEPOSIT', 7),
#  ('BALANCE_CHECK', 13),
#  ('TRANSFER', 8),
#  ('WITHDRAW', 8),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('LOAN_PAYMENT', 12),
#  ('DEPOSIT', 7),
#  ('WITHDRAW', 8),
#  ('TRANSFER', 8),
#  ('BALANCE_CHECK', 13),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
#  ('WITHDRAW', 8),
#  ('LOAN_PAYMENT', 12),
#  ('DEPOSIT', 7),
#  ('TRANSFER', 8),
# ...

# %%
#11
rdd.filter(lambda x: x == "DEPOSIT").collect()
# Out:
# ['DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT',
#  'DEPOSIT']

# %%
#12
rdd.filter(lambda x: x == "WITHDRAW").collect()
# Out:
# ['WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW']

# %%
#13
rdd.filter(lambda x: x == "WITHDRAW").collect()
# Out:
# ['WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW',
#  'WITHDRAW']

# %%
#14
rdd.filter(lambda x: x == "LOAN_PAYMENT").collect()
# Out:
# ['LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT',
#  'LOAN_PAYMENT']

# %%
#15
rdd.filter(lambda x: "CHECK" in x).collect()
# Out:
# ['BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK']

# %%
#16
rdd.filter(lambda x: x != "DEPOSIT").collect()
# Out:
# ['WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'WITHDRAW',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'BALANCE_CHECK']

# %%
#17
rdd.filter(lambda x: x != "TRANSFER").collect()
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'DEPOSIT',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'DEPOSIT',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'DEPOSIT']

# %%
#18
rdd.filter(lambda x: x != "TRANSFER").collect()
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'DEPOSIT',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'DEPOSIT',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'DEPOSIT']

# %%
#19
rdd.filter(lambda x: len(x) < 10).collect()
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'DEPOSIT']

# %%
#20
rdd.filter(lambda x: x.startswith("B")).collect()
# Out:
# ['BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK',
#  'BALANCE_CHECK']

# %%
#21
rdd.map(lambda x: "BANK_" + x).collect()
# Out:
# ['BANK_DEPOSIT',
#  'BANK_WITHDRAW',
#  'BANK_TRANSFER',
#  'BANK_DEPOSIT',
#  'BANK_BALANCE_CHECK',
#  'BANK_TRANSFER',
#  'BANK_DEPOSIT',
#  'BANK_WITHDRAW',
#  'BANK_LOAN_PAYMENT',
#  'BANK_DEPOSIT',
#  'BANK_TRANSFER',
#  'BANK_WITHDRAW',
#  'BANK_DEPOSIT',
#  'BANK_BALANCE_CHECK',
#  'BANK_TRANSFER',
#  'BANK_DEPOSIT',
#  'BANK_WITHDRAW',
#  'BANK_LOAN_PAYMENT',
#  'BANK_TRANSFER',
#  'BANK_DEPOSIT',
#  'BANK_WITHDRAW',
#  'BANK_DEPOSIT',
#  'BANK_TRANSFER',
#  'BANK_BALANCE_CHECK',
#  'BANK_WITHDRAW',
#  'BANK_DEPOSIT',
#  'BANK_TRANSFER',
#  'BANK_LOAN_PAYMENT',
#  'BANK_DEPOSIT',
#  'BANK_WITHDRAW',
#  'BANK_TRANSFER',
#  'BANK_DEPOSIT',
#  'BANK_BALANCE_CHECK',
#  'BANK_TRANSFER',
#  'BANK_WITHDRAW',
#  'BANK_DEPOSIT',
#  'BANK_TRANSFER',
#  'BANK_LOAN_PAYMENT',
#  'BANK_DEPOSIT',
#  'BANK_WITHDRAW',
#  'BANK_TRANSFER',
#  'BANK_BALANCE_CHECK',
#  'BANK_DEPOSIT',
#  'BANK_TRANSFER',
#  'BANK_WITHDRAW',
#  'BANK_LOAN_PAYMENT',
#  'BANK_DEPOSIT',
#  'BANK_TRANSFER',
# ...

# %%
#22
rdd.map(lambda x: x + "_2025").collect()
# Out:
# ['DEPOSIT_2025',
#  'WITHDRAW_2025',
#  'TRANSFER_2025',
#  'DEPOSIT_2025',
#  'BALANCE_CHECK_2025',
#  'TRANSFER_2025',
#  'DEPOSIT_2025',
#  'WITHDRAW_2025',
#  'LOAN_PAYMENT_2025',
#  'DEPOSIT_2025',
#  'TRANSFER_2025',
#  'WITHDRAW_2025',
#  'DEPOSIT_2025',
#  'BALANCE_CHECK_2025',
#  'TRANSFER_2025',
#  'DEPOSIT_2025',
#  'WITHDRAW_2025',
#  'LOAN_PAYMENT_2025',
#  'TRANSFER_2025',
#  'DEPOSIT_2025',
#  'WITHDRAW_2025',
#  'DEPOSIT_2025',
#  'TRANSFER_2025',
#  'BALANCE_CHECK_2025',
#  'WITHDRAW_2025',
#  'DEPOSIT_2025',
#  'TRANSFER_2025',
#  'LOAN_PAYMENT_2025',
#  'DEPOSIT_2025',
#  'WITHDRAW_2025',
#  'TRANSFER_2025',
#  'DEPOSIT_2025',
#  'BALANCE_CHECK_2025',
#  'TRANSFER_2025',
#  'WITHDRAW_2025',
#  'DEPOSIT_2025',
#  'TRANSFER_2025',
#  'LOAN_PAYMENT_2025',
#  'DEPOSIT_2025',
#  'WITHDRAW_2025',
#  'TRANSFER_2025',
#  'BALANCE_CHECK_2025',
#  'DEPOSIT_2025',
#  'TRANSFER_2025',
#  'WITHDRAW_2025',
#  'LOAN_PAYMENT_2025',
#  'DEPOSIT_2025',
#  'TRANSFER_2025',
# ...

# %%
#23
rdd.map(lambda x: len(x)).collect()
# Out:
# [7,
#  8,
#  8,
#  7,
#  13,
#  8,
#  7,
#  8,
#  12,
#  7,
#  8,
#  8,
#  7,
#  13,
#  8,
#  7,
#  8,
#  12,
#  8,
#  7,
#  8,
#  7,
#  8,
#  13,
#  8,
#  7,
#  8,
#  12,
#  7,
#  8,
#  8,
#  7,
#  13,
#  8,
#  8,
#  7,
#  8,
#  12,
#  7,
#  8,
#  8,
#  13,
#  7,
#  8,
#  8,
#  12,
#  7,
#  8,
#  13,
#  7]

# %%
#24
rdd.map(lambda x: len(x)).collect()
# Out:
# [7,
#  8,
#  8,
#  7,
#  13,
#  8,
#  7,
#  8,
#  12,
#  7,
#  8,
#  8,
#  7,
#  13,
#  8,
#  7,
#  8,
#  12,
#  8,
#  7,
#  8,
#  7,
#  8,
#  13,
#  8,
#  7,
#  8,
#  12,
#  7,
#  8,
#  8,
#  7,
#  13,
#  8,
#  8,
#  7,
#  8,
#  12,
#  7,
#  8,
#  8,
#  13,
#  7,
#  8,
#  8,
#  12,
#  7,
#  8,
#  13,
#  7]

# %%
#25
rdd.map(lambda x: (x, 1)).collect()
# Out:
# [('DEPOSIT', 1),
#  ('WITHDRAW', 1),
#  ('TRANSFER', 1),
#  ('DEPOSIT', 1),
#  ('BALANCE_CHECK', 1),
#  ('TRANSFER', 1),
#  ('DEPOSIT', 1),
#  ('WITHDRAW', 1),
#  ('LOAN_PAYMENT', 1),
#  ('DEPOSIT', 1),
#  ('TRANSFER', 1),
#  ('WITHDRAW', 1),
#  ('DEPOSIT', 1),
#  ('BALANCE_CHECK', 1),
#  ('TRANSFER', 1),
#  ('DEPOSIT', 1),
#  ('WITHDRAW', 1),
#  ('LOAN_PAYMENT', 1),
#  ('TRANSFER', 1),
#  ('DEPOSIT', 1),
#  ('WITHDRAW', 1),
#  ('DEPOSIT', 1),
#  ('TRANSFER', 1),
#  ('BALANCE_CHECK', 1),
#  ('WITHDRAW', 1),
#  ('DEPOSIT', 1),
#  ('TRANSFER', 1),
#  ('LOAN_PAYMENT', 1),
#  ('DEPOSIT', 1),
#  ('WITHDRAW', 1),
#  ('TRANSFER', 1),
#  ('DEPOSIT', 1),
#  ('BALANCE_CHECK', 1),
#  ('TRANSFER', 1),
#  ('WITHDRAW', 1),
#  ('DEPOSIT', 1),
#  ('TRANSFER', 1),
#  ('LOAN_PAYMENT', 1),
#  ('DEPOSIT', 1),
#  ('WITHDRAW', 1),
#  ('TRANSFER', 1),
#  ('BALANCE_CHECK', 1),
#  ('DEPOSIT', 1),
#  ('TRANSFER', 1),
#  ('WITHDRAW', 1),
#  ('LOAN_PAYMENT', 1),
#  ('DEPOSIT', 1),
#  ('TRANSFER', 1),
# ...

# %%
#26
rdd.map(lambda x: "CASH_DEPOSIT" if x == "DEPOSIT" else x).collect()
# Out:
# ['CASH_DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'CASH_DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'CASH_DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'CASH_DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'CASH_DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'CASH_DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'CASH_DEPOSIT',
#  'WITHDRAW',
#  'CASH_DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'CASH_DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'CASH_DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'CASH_DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'CASH_DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'CASH_DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'CASH_DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'CASH_DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'CASH_DEPOSIT']

# %%
#27
rdd.map(lambda x: "CASH_WITHDRAWAL" if x == "WITHDRAW" else x).collect()
# Out:
# ['DEPOSIT',
#  'CASH_WITHDRAWAL',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'CASH_WITHDRAWAL',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'CASH_WITHDRAWAL',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'CASH_WITHDRAWAL',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'DEPOSIT',
#  'CASH_WITHDRAWAL',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'CASH_WITHDRAWAL',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'CASH_WITHDRAWAL',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'CASH_WITHDRAWAL',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'CASH_WITHDRAWAL',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'TRANSFER',
#  'CASH_WITHDRAWAL',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT']

# %%
#28
rdd.map(lambda x: "CASH_WITHDRAWAL" if x == "WITHDRAW" else x).collect()
# Out:
# ['DEPOSIT',
#  'CASH_WITHDRAWAL',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'CASH_WITHDRAWAL',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'CASH_WITHDRAWAL',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'CASH_WITHDRAWAL',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'DEPOSIT',
#  'CASH_WITHDRAWAL',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'CASH_WITHDRAWAL',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'CASH_WITHDRAWAL',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'CASH_WITHDRAWAL',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'CASH_WITHDRAWAL',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'TRANSFER',
#  'CASH_WITHDRAWAL',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT']

# %%
#29
rdd.map(lambda x: x[0]).collect()
# Out:
# ['D',
#  'W',
#  'T',
#  'D',
#  'B',
#  'T',
#  'D',
#  'W',
#  'L',
#  'D',
#  'T',
#  'W',
#  'D',
#  'B',
#  'T',
#  'D',
#  'W',
#  'L',
#  'T',
#  'D',
#  'W',
#  'D',
#  'T',
#  'B',
#  'W',
#  'D',
#  'T',
#  'L',
#  'D',
#  'W',
#  'T',
#  'D',
#  'B',
#  'T',
#  'W',
#  'D',
#  'T',
#  'L',
#  'D',
#  'W',
#  'T',
#  'B',
#  'D',
#  'T',
#  'W',
#  'L',
#  'D',
#  'T',
#  'B',
#  'D']

# %%
#30
rdd.map(lambda x: x[-1]).collect()
# Out:
# ['T',
#  'W',
#  'R',
#  'T',
#  'K',
#  'R',
#  'T',
#  'W',
#  'T',
#  'T',
#  'R',
#  'W',
#  'T',
#  'K',
#  'R',
#  'T',
#  'W',
#  'T',
#  'R',
#  'T',
#  'W',
#  'T',
#  'R',
#  'K',
#  'W',
#  'T',
#  'R',
#  'T',
#  'T',
#  'W',
#  'R',
#  'T',
#  'K',
#  'R',
#  'W',
#  'T',
#  'R',
#  'T',
#  'T',
#  'W',
#  'R',
#  'K',
#  'T',
#  'R',
#  'W',
#  'T',
#  'T',
#  'R',
#  'K',
#  'T']

# %%
#31
rdd.distinct().collect()
# Out:
# ['DEPOSIT', 'WITHDRAW', 'TRANSFER', 'BALANCE_CHECK', 'LOAN_PAYMENT']

# %%
#32
rdd.distinct().count()
# Out:
# 5

# %%
#33
rdd.distinct().sortBy(lambda x: x).collect()
# Out:
# ['BALANCE_CHECK', 'DEPOSIT', 'LOAN_PAYMENT', 'TRANSFER', 'WITHDRAW']

# %%
#34
rdd.distinct().filter(lambda x: "PAYMENT" in x).collect()
# Out:
# ['LOAN_PAYMENT']

# %%
#35
rdd.distinct().filter(lambda x: "CHECK" in x).collect()
# Out:
# ['BALANCE_CHECK']

# %%
#36
rdd.countByValue()
# Out:
# defaultdict(int,
#             {'DEPOSIT': 16,
#              'WITHDRAW': 10,
#              'TRANSFER': 13,
#              'BALANCE_CHECK': 6,
#              'LOAN_PAYMENT': 5})

# %%
#37
freq = rdd.countByValue()

max(freq.items(), key=lambda x: x[1])
# Out:
# ('DEPOSIT', 16)

# %%
#38
freq = rdd.countByValue()

min(freq.items(), key=lambda x: x[1])
# Out:
# ('LOAN_PAYMENT', 5)

# %%
#39
freq = rdd.countByValue()

min(freq.items(), key=lambda x: x[1])
# Out:
# ('LOAN_PAYMENT', 5)

# %%
#40
freq = rdd.countByValue()

for transaction, count in freq.items():
    if count > 5:
        print(transaction, count)
# Out:
# DEPOSIT 16
# WITHDRAW 10
# TRANSFER 13
# BALANCE_CHECK 6

# %%
extra_transactions = [
"DEPOSIT",
"ATM_WITHDRAWAL",
"TRANSFER",
"MOBILE_RECHARGE",
"BALANCE_CHECK"
]

rdd2 = spark.sparkContext.parallelize(extra_transactions)

# %%
#41
rdd.union(rdd2).collect()
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'TRANSFER',
#  'DEPOSIT',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'DEPOSIT',
#  'BALANCE_CHECK',
#  'TRANSFER',
#  'WITHDRAW',
#  'DEPOSIT',
#  'TRANSFER',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'TRANSFER',
#  'WITHDRAW',
#  'LOAN_PAYMENT',
#  'DEPOSIT',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'DEPOSIT',
#  'DEPOSIT',
#  'ATM_WITHDRAWAL',
#  'TRANSFER',
#  'MOBILE_RECHARGE',
#  'BALANCE_CHECK']

# %%
#42
rdd.union(rdd2).count()
# Out:
# 55

# %%
#43
rdd.union(rdd2).distinct().collect()
# Out:
# ['DEPOSIT',
#  'WITHDRAW',
#  'TRANSFER',
#  'BALANCE_CHECK',
#  'LOAN_PAYMENT',
#  'ATM_WITHDRAWAL',
#  'MOBILE_RECHARGE']

# %%
#44
rdd2.subtract(rdd).collect()
# Out:
# ['ATM_WITHDRAWAL', 'MOBILE_RECHARGE']

# %%
#45
rdd.union(rdd2).countByValue()
# Out:
# defaultdict(int,
#             {'DEPOSIT': 17,
#              'WITHDRAW': 10,
#              'TRANSFER': 14,
#              'BALANCE_CHECK': 7,
#              'LOAN_PAYMENT': 5,
#              'ATM_WITHDRAWAL': 1,
#              'MOBILE_RECHARGE': 1})

# %%
#46
rdd3 = spark.sparkContext.parallelize([
"DEPOSIT",
"TRANSFER",
"BALANCE_CHECK",
"CREDIT_CARD_PAYMENT",
"ATM_WITHDRAWAL"
])

rdd.intersection(rdd3).collect()
# Out:
# ['DEPOSIT', 'TRANSFER', 'BALANCE_CHECK']

# %%
#47
rdd.intersection(rdd3).count()
# Out:
# 3

# %%
#48
rdd.intersection(rdd3).sortBy(lambda x: x).collect()
# Out:
# ['BALANCE_CHECK', 'DEPOSIT', 'TRANSFER']

# %%
#49
rdd.intersection(rdd3) \
   .filter(lambda x: "CHECK" in x) \
   .collect()
# Out:
# ['BALANCE_CHECK']

# %%
#50
rdd.intersection(rdd3) \
   .filter(lambda x: "TRANSFER" in x) \
   .collect()
# Out:
# ['TRANSFER']

# %%
amounts = [
500,1200,3000,4500,800,950,
1100,2500,4000,6000,
750,1800,2200,3300,4700,
5200,1500,2600,3700,4800,
5900,6200,700,900,1400,
1750,2100,2900,3600,4300,
5100,5800,6500,7200,8100,
9200,10500,12000,13500,15000,
17000,19000,22000,25000,28000,
30000,32000,35000,38000,40000
]

amount_rdd = spark.sparkContext.parallelize(amounts)

# %%
#51
amount_rdd.reduce(lambda x, y: x + y)
# Out:
# 463750

# %%
#52
amount_rdd.reduce(lambda x, y: x + y) / amount_rdd.count()
# Out:
# 9275.0

# %%
#53
amount_rdd.reduce(lambda x, y: x if x > y else y)
# Out:
# 40000

# %%
#54
amount_rdd.reduce(lambda x, y: x if x < y else y)
# Out:
# 500

# %%
#55
amount_rdd.filter(lambda x: x > 10000).collect()
# Out:
# [10500,
#  12000,
#  13500,
#  15000,
#  17000,
#  19000,
#  22000,
#  25000,
#  28000,
#  30000,
#  32000,
#  35000,
#  38000,
#  40000]

# %%
#56
amount_rdd.filter(lambda x: x < 2000).collect()
# Out:
# [500, 1200, 800, 950, 1100, 750, 1800, 1500, 700, 900, 1400, 1750]

# %%
#57
amount_rdd.map(lambda x: x + 500).collect()
# Out:
# [1000,
#  1700,
#  3500,
#  5000,
#  1300,
#  1450,
#  1600,
#  3000,
#  4500,
#  6500,
#  1250,
#  2300,
#  2700,
#  3800,
#  5200,
#  5700,
#  2000,
#  3100,
#  4200,
#  5300,
#  6400,
#  6700,
#  1200,
#  1400,
#  1900,
#  2250,
#  2600,
#  3400,
#  4100,
#  4800,
#  5600,
#  6300,
#  7000,
#  7700,
#  8600,
#  9700,
#  11000,
#  12500,
#  14000,
#  15500,
#  17500,
#  19500,
#  22500,
#  25500,
#  28500,
#  30500,
#  32500,
#  35500,
#  38500,
#  40500]

# %%
#58
amount_rdd.map(lambda x: x * 1.10).collect()
# Out:
# [550.0,
#  1320.0,
#  3300.0000000000005,
#  4950.0,
#  880.0000000000001,
#  1045.0,
#  1210.0,
#  2750.0,
#  4400.0,
#  6600.000000000001,
#  825.0000000000001,
#  1980.0000000000002,
#  2420.0,
#  3630.0000000000005,
#  5170.0,
#  5720.000000000001,
#  1650.0000000000002,
#  2860.0000000000005,
#  4070.0000000000005,
#  5280.0,
#  6490.000000000001,
#  6820.000000000001,
#  770.0000000000001,
#  990.0000000000001,
#  1540.0000000000002,
#  1925.0000000000002,
#  2310.0,
#  3190.0000000000005,
#  3960.0000000000005,
#  4730.0,
#  5610.0,
#  6380.000000000001,
#  7150.000000000001,
#  7920.000000000001,
#  8910.0,
#  10120.0,
#  11550.000000000002,
#  13200.000000000002,
#  14850.000000000002,
#  16500.0,
#  18700.0,
#  20900.0,
#  24200.000000000004,
#  27500.000000000004,
#  30800.000000000004,
#  33000.0,
#  35200.0,
#  38500.0,
#  41800.0,
#  44000.0]

# %%
#59
amount_rdd.sortBy(lambda x: x).collect()
# Out:
# [500,
#  700,
#  750,
#  800,
#  900,
#  950,
#  1100,
#  1200,
#  1400,
#  1500,
#  1750,
#  1800,
#  2100,
#  2200,
#  2500,
#  2600,
#  2900,
#  3000,
#  3300,
#  3600,
#  3700,
#  4000,
#  4300,
#  4500,
#  4700,
#  4800,
#  5100,
#  5200,
#  5800,
#  5900,
#  6000,
#  6200,
#  6500,
#  7200,
#  8100,
#  9200,
#  10500,
#  12000,
#  13500,
#  15000,
#  17000,
#  19000,
#  22000,
#  25000,
#  28000,
#  30000,
#  32000,
#  35000,
#  38000,
#  40000]

# %%
#60
amount_rdd.sortBy(lambda x: x, ascending=False).collect()
# Out:
# [40000,
#  38000,
#  35000,
#  32000,
#  30000,
#  28000,
#  25000,
#  22000,
#  19000,
#  17000,
#  15000,
#  13500,
#  12000,
#  10500,
#  9200,
#  8100,
#  7200,
#  6500,
#  6200,
#  6000,
#  5900,
#  5800,
#  5200,
#  5100,
#  4800,
#  4700,
#  4500,
#  4300,
#  4000,
#  3700,
#  3600,
#  3300,
#  3000,
#  2900,
#  2600,
#  2500,
#  2200,
#  2100,
#  1800,
#  1750,
#  1500,
#  1400,
#  1200,
#  1100,
#  950,
#  900,
#  800,
#  750,
#  700,
#  500]

# %%
#61
amount_rdd.top(10)
# Out:
# [40000, 38000, 35000, 32000, 30000, 28000, 25000, 22000, 19000, 17000]

# %%
#62
amount_rdd.top(10)
# Out:
# [40000, 38000, 35000, 32000, 30000, 28000, 25000, 22000, 19000, 17000]

# %%
#63
amount_rdd.top(10)
# Out:
# [40000, 38000, 35000, 32000, 30000, 28000, 25000, 22000, 19000, 17000]

# %%
#64
amount_rdd.filter(lambda x: x > 20000).count()
# Out:
# 8

# %%
#65
amount_rdd.filter(lambda x: x > 10000) \
          .reduce(lambda x, y: x + y)
# Out:
# 337000

# %%
customer_comments = [
"service was excellent",
"mobile banking is easy",
"transfer completed quickly",
"deposit process was smooth",
"excellent customer support",
"loan payment completed successfully",
"banking app is excellent",
"service is fast and reliable"
]

comment_rdd = spark.sparkContext.parallelize(customer_comments)

# %%
#66
comment_rdd.flatMap(lambda x: x.split()).collect()
# Out:
# ['service',
#  'was',
#  'excellent',
#  'mobile',
#  'banking',
#  'is',
#  'easy',
#  'transfer',
#  'completed',
#  'quickly',
#  'deposit',
#  'process',
#  'was',
#  'smooth',
#  'excellent',
#  'customer',
#  'support',
#  'loan',
#  'payment',
#  'completed',
#  'successfully',
#  'banking',
#  'app',
#  'is',
#  'excellent',
#  'service',
#  'is',
#  'fast',
#  'and',
#  'reliable']

# %%
#67
comment_rdd.flatMap(lambda x: x.split()).count()
# Out:
# 30

# %%
#68
comment_rdd.flatMap(lambda x: x.split()) \
           .distinct() \
           .collect()
# Out:
# ['service',
#  'banking',
#  'easy',
#  'transfer',
#  'deposit',
#  'support',
#  'payment',
#  'successfully',
#  'app',
#  'fast',
#  'and',
#  'reliable',
#  'was',
#  'excellent',
#  'mobile',
#  'is',
#  'completed',
#  'quickly',
#  'process',
#  'smooth',
#  'customer',
#  'loan']

# %%
#69
comment_rdd.flatMap(lambda x: x.split()) \
           .sortBy(lambda x: x) \
           .collect()
# Out:
# ['and',
#  'app',
#  'banking',
#  'banking',
#  'completed',
#  'completed',
#  'customer',
#  'deposit',
#  'easy',
#  'excellent',
#  'excellent',
#  'excellent',
#  'fast',
#  'is',
#  'is',
#  'is',
#  'loan',
#  'mobile',
#  'payment',
#  'process',
#  'quickly',
#  'reliable',
#  'service',
#  'service',
#  'smooth',
#  'successfully',
#  'support',
#  'transfer',
#  'was',
#  'was']

# %%
#70
comment_rdd.flatMap(lambda x: x.split()) \
           .countByValue()
# Out:
# defaultdict(int,
#             {'service': 2,
#              'was': 2,
#              'excellent': 3,
#              'mobile': 1,
#              'banking': 2,
#              'is': 3,
#              'easy': 1,
#              'transfer': 1,
#              'completed': 2,
#              'quickly': 1,
#              'deposit': 1,
#              'process': 1,
#              'smooth': 1,
#              'customer': 1,
#              'support': 1,
#              'loan': 1,
#              'payment': 1,
#              'successfully': 1,
#              'app': 1,
#              'fast': 1,
#              'and': 1,
#              'reliable': 1})

# %%
#71
comment_rdd.flatMap(lambda x: x.split()) \
           .filter(lambda x: "service" in x) \
           .collect()
# Out:
# ['service', 'service']

# %%
#72
comment_rdd.flatMap(lambda x: x.split()) \
           .filter(lambda x: "excellent" in x) \
           .collect()
# Out:
# ['excellent', 'excellent', 'excellent']

# %%
#73
comment_rdd.flatMap(lambda x: x.split()) \
           .map(lambda x: x.upper()) \
           .collect()
# Out:
# ['SERVICE',
#  'WAS',
#  'EXCELLENT',
#  'MOBILE',
#  'BANKING',
#  'IS',
#  'EASY',
#  'TRANSFER',
#  'COMPLETED',
#  'QUICKLY',
#  'DEPOSIT',
#  'PROCESS',
#  'WAS',
#  'SMOOTH',
#  'EXCELLENT',
#  'CUSTOMER',
#  'SUPPORT',
#  'LOAN',
#  'PAYMENT',
#  'COMPLETED',
#  'SUCCESSFULLY',
#  'BANKING',
#  'APP',
#  'IS',
#  'EXCELLENT',
#  'SERVICE',
#  'IS',
#  'FAST',
#  'AND',
#  'RELIABLE']

# %%
#74
comment_rdd.flatMap(lambda x: x.split()) \
           .reduce(lambda x, y: x if len(x) > len(y) else y)
# Out:
# 'successfully'

# %%
#75
comment_rdd.flatMap(lambda x: x.split()) \
           .reduce(lambda x, y: x if len(x) < len(y) else y)
# Out:
# 'is'

# %%
#76
word_freq = comment_rdd.flatMap(lambda x: x.split()) \
                       .countByValue()

max(word_freq.items(), key=lambda x: x[1])
# Out:
# ('excellent', 3)

# %%
#77
word_freq = comment_rdd.flatMap(lambda x: x.split()) \
                       .countByValue()

min(word_freq.items(), key=lambda x: x[1])
# Out:
# ('mobile', 1)

# %%
#78
comment_rdd.flatMap(lambda x: x.split()) \
           .filter(lambda x: x.startswith("b")) \
           .count()
# Out:
# 2

# %%
#79
comment_rdd.flatMap(lambda x: x.split()) \
           .filter(lambda x: x.endswith("ly")) \
           .count()
# Out:
# 2

# %%
#80
comment_rdd.flatMap(lambda x: x.split()) \
           .filter(lambda x: x.endswith("ly")) \
           .count()
# Out:
# 2

# %%
#81
deposit_count = rdd.filter(lambda x: x == "DEPOSIT").count()

(deposit_count / rdd.count()) * 100
# Out:
# 32.0

# %%
#82
transfer_count = rdd.filter(lambda x: x == "TRANSFER").count()

(transfer_count / rdd.count()) * 100
# Out:
# 26.0

# %%
#83
withdraw_count = rdd.filter(lambda x: x == "WITHDRAW").count()

(withdraw_count / rdd.count()) * 100
# Out:
# 20.0

# %%
#84
freq = rdd.countByValue()

max(freq.items(), key=lambda x: x[1])
# Out:
# ('DEPOSIT', 16)

# %%
#85
freq = rdd.countByValue()

min(freq.items(), key=lambda x: x[1])
# Out:
# ('LOAN_PAYMENT', 5)

# %%
#86
print("Total Transactions:", rdd.count())
print("Unique Transactions:", rdd.distinct().count())
print("Most Frequent:", max(rdd.countByValue().items(), key=lambda x: x[1]))
# Out:
# Total Transactions: 50
# Unique Transactions: 5
# Most Frequent: ('DEPOSIT', 16)

# %%
#87
print(rdd.distinct().sortBy(lambda x: x).collect())
# Out:
# ['BALANCE_CHECK', 'DEPOSIT', 'LOAN_PAYMENT', 'TRANSFER', 'WITHDRAW']

# %%
#88
freq = rdd.countByValue()

for transaction, count in freq.items():
    print(transaction, count)
# Out:
# DEPOSIT 16
# WITHDRAW 10
# TRANSFER 13
# BALANCE_CHECK 6
# LOAN_PAYMENT 5

# %%
#89
rdd.distinct().saveAsTextFile("unique_transactions")

# %%
#90
rdd.map(lambda x: (x, 1)) \
   .reduceByKey(lambda a, b: a + b) \
   .saveAsTextFile("transaction_frequencies")

# %%
#91
rdd.count()
# Out:
# 50

# %%
#92
freq = rdd.countByValue()

sorted(freq.items(), key=lambda x: x[1], reverse=True)[:3]

# %%
#93
freq = rdd.countByValue()

sorted(freq.items(), key=lambda x: x[1])[:3]
# Out:
# [('LOAN_PAYMENT', 5), ('BALANCE_CHECK', 6), ('WITHDRAW', 10)]

# %%
#94
freq = rdd.countByValue()

sorted(freq.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('DEPOSIT', 16),
#  ('TRANSFER', 13),
#  ('WITHDRAW', 10),
#  ('BALANCE_CHECK', 6),
#  ('LOAN_PAYMENT', 5)]

# %%
#95
freq = rdd.countByValue()

print("Total Activities:", rdd.count())
print("Unique Activities:", rdd.distinct().count())
print("Most Common:", max(freq.items(), key=lambda x: x[1]))
print("Least Common:", min(freq.items(), key=lambda x: x[1]))
# Out:
# Total Activities: 50
# Unique Activities: 5
# Most Common: ('DEPOSIT', 16)
# Least Common: ('LOAN_PAYMENT', 5)

# %%
#96
amount_rdd.reduce(lambda x, y: x + y)
# Out:
# 463750

# %%
#97
amount_rdd.reduce(lambda x, y: x + y) / amount_rdd.count()
# Out:
# 9275.0

# %%
#98
amount_rdd.filter(lambda x: x > 20000).collect()
# Out:
# [22000, 25000, 28000, 30000, 32000, 35000, 38000, 40000]

# %%
#99
amount_rdd.filter(lambda x: x < 1000).collect()
# Out:
# [500, 800, 950, 750, 700, 900]

# %%
#100
print("===== BANK TRANSACTION DASHBOARD =====")

print("Total Transactions:",
      rdd.count())

print("Unique Transaction Types:",
      rdd.distinct().count())

print("Most Common Transaction:",
      max(rdd.countByValue().items(),
          key=lambda x: x[1]))

print("Least Common Transaction:",
      min(rdd.countByValue().items(),
          key=lambda x: x[1]))

print("Total Money Processed:",
      amount_rdd.reduce(lambda x, y: x + y))

print("Average Amount:",
      amount_rdd.reduce(lambda x, y: x + y) / amount_rdd.count())

print("Top 10 Amounts:",
      amount_rdd.top(10))
# Out:
# ===== BANK TRANSACTION DASHBOARD =====
# Total Transactions: 50
# Unique Transaction Types: 5
# Most Common Transaction: ('DEPOSIT', 16)
# Least Common Transaction: ('LOAN_PAYMENT', 5)
# Total Money Processed: 463750
# Average Amount: 9275.0
# Top 10 Amounts: [40000, 38000, 35000, 32000, 30000, 28000, 25000, 22000, 19000, 17000]
